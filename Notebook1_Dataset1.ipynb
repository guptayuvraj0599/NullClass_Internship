# %%
import pandas as pd

# %%
data=r'C:\NullClass Internship Data Analysis\Data1_Task1.csv'

# %%
df=pd.read_csv(data)

# %%
df.head(20)
# Out:
#                  Company Name       Job Title                      Role  \
# 0                   Accenture  UI/UX Designer  User Experience Designer
# 1                      Airbnb  UI/UX Designer  User Experience Designer
# 2                      Amazon  UI/UX Designer  User Experience Designer
# 3                     Dropbox  UI/UX Designer  User Experience Designer
# 4             Facebook (Meta)  UI/UX Designer  User Experience Designer
# 5                      Google  UI/UX Designer  User Experience Designer
# 6        Hewlett Packard (HP)  UI/UX Designer  User Experience Designer
# 7                     Infosys  UI/UX Designer  User Experience Designer
# 8                   Microsoft  UI/UX Designer  User Experience Designer
# 9                     Netflix  UI/UX Designer  User Experience Designer
# 10                     Oracle  UI/UX Designer  User Experience Designer
# 11                     PayPal  UI/UX Designer  User Experience Designer
# ...

# %%
df.index=df.index+1

# %%
df.head(21)
# Out:
#                  Company Name       Job Title                      Role  \
# 1                   Accenture  UI/UX Designer  User Experience Designer
# 2                      Airbnb  UI/UX Designer  User Experience Designer
# 3                      Amazon  UI/UX Designer  User Experience Designer
# 4                     Dropbox  UI/UX Designer  User Experience Designer
# 5             Facebook (Meta)  UI/UX Designer  User Experience Designer
# 6                      Google  UI/UX Designer  User Experience Designer
# 7        Hewlett Packard (HP)  UI/UX Designer  User Experience Designer
# 8                     Infosys  UI/UX Designer  User Experience Designer
# 9                   Microsoft  UI/UX Designer  User Experience Designer
# 10                    Netflix  UI/UX Designer  User Experience Designer
# 11                     Oracle  UI/UX Designer  User Experience Designer
# 12                     PayPal  UI/UX Designer  User Experience Designer
# ...

# %%
df.columns
# Out:
# Index(['Company Name', 'Job Title', 'Role', 'Count Of UI/UX Designers'], dtype='object')
